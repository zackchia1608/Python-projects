# %% [markdown]
# # Webscraping Tutorial

# %% [markdown]
# This notebook will attempt to scrape the corporate information from a list of selected companies. This was done as a favor for a friend.

# %% [markdown]
# # Importing Libraries and Text File

# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import requests
from tqdm import tqdm_notebook

# %% [markdown]
# First, I will look at the URL list from the text file and import it into python as a list

# %%
# Import URL text file into list
url_list = []
url = open("sgx_links.txt", 'r', newline=None)
for line in url:
    url_list.append(line)

# %%
# Remove \n from the each URL
url_list = [i.replace('\n', '') for i in url_list]

# %%
len(url_list)
# Out:
# 707

# %% [markdown]
# Based on the text file, there are 707 URLs in the list.

# %% [markdown]
# # Webscraping

# %% [markdown]
# First, I will create a dataframe to hold the information scraped.

# %%
info = pd.DataFrame(columns=['company_name', 'incorporated', 'incorporated_on', 'ISIN_code', 'registered_office', 'telephone', 'fax', 'email',
                    'secretary', 'website', 'listing', 'listing_board', 'other_stock_exchange', 'registrars', 'registrars_address', 'auditors', 'background'])

# %% [markdown]
# As I will be scraping directly from the SGX website, I will be using Beautiful Soup HTML parser to scrape the information that are needed.

# %%
#Webscrape with BeautifulSoup

info_list = []

for url in tqdm_notebook(url_list):

    URL = url
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    company_name = soup.find(id="ctl07_compFullNameLabel").text
    incorporated = soup.find(id="ctl07_incorporatedLabel").text
    incorporated_on = soup.find(id='ctl07_incorpOnLabel').text
    isin_code = soup.find(id='ctl07_isinCodeLabel').text
    registered_office = soup.find(
        'dt', text='Registered Office :').findNext("dd").text
    telephone = soup.find('dt', text='Telephone :').findNext("dd").text
    fax = soup.find('dt', text='Fax :').findNext("dd").text
    email = soup.find('dt', text='Email :').findNext("dd").text
    secretary = soup.find('dt', text='Secretary :').findNext("dd").text
    website = soup.find(
        'dt', text='Link to Internet Website :').findNext("dd").text
    listing = soup.find(id='ctl07_listingDateLabel').text
    listing_board = soup.find(id='ctl07_lbllistingBoard').text

    # Not all url has this row so the webscrape will try to scrape it and return NAN if none
    try:
        other_stock_exchange = soup.find(
            text='OTHER STOCK EXCHANGE LISTINGS').findNext('dd').text
    except (AttributeError):
        other_stock_exchange = np.nan

    registrars = soup.find(
        text='REGISTRARS / TRANSFER AGENTS & ADDRESS').findNext('dd').text
    registrars_address = soup.find(
        text='REGISTRARS / TRANSFER AGENTS & ADDRESS').findNext('dd').findNext('dd').text
    auditors = soup.find(text='AUDITORS').findNext('dd').text
    background = soup.find(id='litIPOCompany').text

    info_list.append([company_name, incorporated, incorporated_on, isin_code, registered_office, telephone, fax, email,
                     secretary, website, listing, listing_board, other_stock_exchange, registrars, registrars_address, auditors, background])
# Out:
# /var/folders/sz/qlhtygjx661flzpy8w5byj240000gn/T/ipykernel_26933/2163992587.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for url in tqdm_notebook(url_list):
#   0%|          | 0/707 [00:00<?, ?it/s]

# %%
#Append it to the pandas dataframe
info = info.append(pd.DataFrame(info_list, columns=info.columns))
# Out:
# /var/folders/sz/qlhtygjx661flzpy8w5byj240000gn/T/ipykernel_26933/4238377209.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   info = info.append(pd.DataFrame(info_list, columns = info.columns))

# %% [markdown]
# Finally, I will need to clean the data to remove all the \r and \n markings

# %%
info = info.replace('\n', '', regex=True)
info = info.replace('\r', '', regex=True)

# %%
info
# Out:
#                                           company_name  \
# 0                                      3CNERGY LIMITED
# 1                                 5E RESOURCES LIMITED
# 2                        8TELECOM INTL HOLDINGS CO LTD
# 3                                           9R LIMITED
# 4                           ABACUS CAPITAL (S) PTE LTD
# ..                                                 ...
# 702                  YUUZOO NETWORKS GROUP CORPORATION
# 703  ZHENENG JINJIANG ENVIRONMENT HOLDING COMPANY L...
# 704                  ZHONGMIN BAIHUI RETAIL GROUP LTD.
# 705                   ZHONGXIN FRUIT AND JUICE LIMITED
# 706                                 ZICO HOLDINGS INC.
#
#                 incorporated incorporated_on     ISIN_code  \
# 0                  SINGAPORE     24 Feb 1973  SG0502000029
# 1                  SINGAPORE     18 Oct 2021  SGXE78399073
# 2                    BERMUDA     05 Jan 2004  BMG3087Y2074
# 3                  SINGAPORE     04 Nov 1993  SGXE45420721
# 4                  SINGAPORE                  SG1BE4000002
# ..                       ...             ...           ...
# 702  VIRGIN ISLANDS, BRITISH     22 Mar 2005  VGG9889R1001
# 703           CAYMAN ISLANDS     08 Sep 2010  KYG9898S1075
# 704                SINGAPORE     17 Sep 2004  SG2C76966531
# 705                SINGAPORE     27 Sep 2002  SG1P25916898
# 706                 MALAYSIA     09 Dec 2010  MYA007968003
#
#                                      registered_office  \
# 0    82 Ubi Avenue 4#05-04 Edward Boustead CentreSi...
# 1    30 Cecil Street#19-08Prudential TowerSingapore...
# 2    Clarendon House2 Church StreetHamilton HM 11Be...
# 3    105 Cecil Street,#12-02 The Octagon,Singapore ...
# 4                                                  NA
# ..                                                 ...
# 702  Jayla PlaceWickhams Cay 1Road TownTortola Brit...
# 703  Grand Pavillion, Hibiscus Way802 West Bay Road...
# 704  160 Robinson RoadSBF Centre#15-06Singapore 068...
# 705  No 25 International Business Park#02-53 German...
# 706  Unit Level 13(A), Main Office Tower,Financial ...
#
#                            telephone                             fax  \
# 0                       65 69708117
# 1
# 2                  (86) 57188225288                 (86) 57188225291
# 3                      65 6601 9500                     65 6601 9600
# 4
# ..                               ...                             ...
# 702                     65 62713468                      65 62758469
# 703                 86 571 87699700                 86 571 88388848.
# 704  86 592 5863888 (Xiamen) 65 644   86 592 5182791 (Xiamen) 65 644
# 705                     65 65572308
# 706                  (65) 6438 7929
#
#                         email                        secretary  \
# 0    enquiries@3cnergy.com.sg                    Cheok Hui Yee
# 1    finance@5e-resources.com              Tan Sey Liy Shirley
# 2
# 3                                        Lai Kuan Loong Victor
# 4
# ..                        ...                              ...
# 702
# 703                            Toh Li Ping AngelaHoon Chi Tern
# 704                                             Chia Foon Yeow
# 705                                             Lee Wei Hsiung
# 706                                   ZICO Secretarial Limited
#
#                               website  \
# 0          http://www.3cnergy.com.sg/
# 1         http://www.5e-resources.com
# 2              http://www.8telecom.cn
# 3             http://www.vikingom.com
# 4
# ..                                ...
# 702             http://www.yuuzoo.com
# 703
# 704  http://www.zhongminbaihui.com.sg
# 705
# 706       http://www.zicoholdings.com
#
#                                                listing listing_board  \
# 0                  Listed on 6 July 1987 on SGX Sesdaq      CATALIST
# 1                    Listed on 12 May 2022 on CATALIST      CATALIST
# 2              Listed on 23 July 2004 on SGX Mainboard     MAINBOARD
# 3                 Listed on 10 August 2021 on CATALIST      CATALIST
# 4              Listed on 22 July 2015 on SGX Mainboard     MAINBOARD
# ..                                                 ...           ...
# 702        Listed on 27 December 2005 on SGX Mainboard     MAINBOARD
# 703           Listed on 3 August 2016 on SGX Mainboard     MAINBOARD
# 704  Listed on 3 September 2013 on SGX Mainboard (2...     MAINBOARD
# 705              Listed on 24 March 2004 on SGX Sesdaq      CATALIST
# 706            Listed on 11 November 2014 on Catalist       CATALIST
#
#                other_stock_exchange  \
# 0    *SINGAPORE EXCHANGE (CATALIST)
# 1    *SINGAPORE EXCHANGE (CATALIST)
# 2          *SINGAPORE EXCHANGE LTD.
# 3    *SINGAPORE EXCHANGE (CATALIST)
# 4          *SINGAPORE EXCHANGE LTD.
# ..                              ...
# 702        *SINGAPORE EXCHANGE LTD.
# 703        *SINGAPORE EXCHANGE LTD.
# 704        *SINGAPORE EXCHANGE LTD.
# 705  *SINGAPORE EXCHANGE (CATALIST)
# 706  *SINGAPORE EXCHANGE (CATALIST)
#
#                                             registrars  \
# 0                TRICOR BARBINDER SHARE REGISTRATIO...
# 1                IN.CORP CORPORATE SERVICES PTE. LT...
# 2                CONYERS CORPORATE SERVICES (BERMUD...
# 3                M & C SERVICES PRIVATE LIMITED    ...
# 4
# ..                                                 ...
# 702              ESTERA MANAGEMENT (BERMUDA) LTD \B...
# 703              BOARDROOM CORPORATE & ADVISORY SER...
# 704              BOARDROOM CORPORATE & ADVISORY SER...
# 705              BOARDROOM CORPORATE & ADVISORY SER...
# 706                   B.A.C.S. PRIVATE LIMITED
#
#                                     registrars_address  \
# 0                80 Robinson Road #02-00 Singapore ...
# 1                30 Cecil Street, #19-08 Prudential...
# 2                Clarendon House  2 Church Street  ...
# 3                112 Robinson Road #05-01, Singapor...
# 4
# ..                                                 ...
# 702              Victoria Place, 5th Floor, 31 Vict...
# 703              1 Harbourfront Avenue, Keppel Bay ...
# 704              1 Harbourfront Avenue, Keppel Bay ...
# 705              1 Harbourfront Avenue, Keppel Bay ...
# 706              77 Robinson Road, #06-03 Robinson ...
#
#                        auditors  \
# 0                    MAZARS LLP
# 1    PRICEWATERHOUSECOOPERS LLP
# 2               FOO KON TAN LLP
# 3             ERNST & YOUNG LLP
# 4
# ..                          ...
# 702
# 703  PRICEWATERHOUSECOOPERS LLP
# 704           ERNST & YOUNG LLP
# 705          MOORE STEPHENS LLP
# 706        BAKER TILLY  TFW LLP
#
#                                             background
# 0            On 30 July 1981, the Company was incor...
# 1            5E Resources Limited ("5E Resources" o...
# 2            The Company was incorporated in Bermud...
# 3            Viking Offshore and Marine Limited was...
# 4            The Funds will NOT be traded on SGX-ST...
# ..                                                 ...
# 702          Headquartered and listed on the SGX ma...
# 703          ZHENENG JINJIANG ENVIRONMENT HOLDING C...
# 704          The Company was incorporated in Singap...
# 705          The Company was incorporated in Singap...
# 706          ZICO Holdings Inc, and its subsidiarie...
#
# [707 rows x 17 columns]

# %% [markdown]
# Finally, I will be exporting the information to a CSV file

# %%
info.to_csv('data_cleaned.csv')
